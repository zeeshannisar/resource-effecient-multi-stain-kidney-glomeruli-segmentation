# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
"""
2D Residual U-Net for lung nodule segmentation.
Adapted from: https://github.com/DuFanXin/deep_residual_unet/blob/master/res_unet.py
"""


def res_block(x, nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same', strides=strides[0])(res_path)
    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same', strides=strides[1])(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1), strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)

    res_path = add([shortcut, res_path])
    return res_path


def encoder(x):
    resblock_units = [3, 4, 6, 3]
    to_decoder = []

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(x)
    main_path = BatchNormalization()(main_path)
    main_path = Activation(activation='relu')(main_path)

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(main_path)

    shortcut = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1))(x)
    shortcut = BatchNormalization()(shortcut)

    main_path = add([shortcut, main_path])
    # first branching to decoder
    to_decoder.append(main_path)

    for units in range(resblock_units[0]):
        main_path = res_block(main_path, [64, 64], [(1, 1), (1, 1)])
    main_path = MaxPooling2D(pool_size=(2, 2))(main_path)    
    to_decoder.append(main_path)

    for units in range(resblock_units[1]):
        main_path = res_block(main_path, [128, 128], [(1, 1), (1, 1)])
    main_path = MaxPooling2D(pool_size=(2, 2))(main_path)    
    to_decoder.append(main_path)
    
    for units in range(resblock_units[2]):
        main_path = res_block(main_path, [256, 256], [(1, 1), (1, 1)])
    main_path = MaxPooling2D(pool_size=(2, 2))(main_path)    
    to_decoder.append(main_path)

    for units in range(resblock_units[3]):
        main_path = res_block(main_path, [512, 512], [(1, 1), (1, 1)])
    main_path = MaxPooling2D(pool_size=(2, 2))(main_path)    
    to_decoder.append(main_path)

    return to_decoder


def decoder(x, from_encoder):
    main_path = UpSampling2D(size=(2, 2))(x)
    main_path = concatenate([main_path, from_encoder[3]], axis=3)
    main_path = res_block(main_path, [256, 256], [(1, 1), (1, 1)])
    
    main_path = UpSampling2D(size=(2, 2))(x)
    main_path = concatenate([main_path, from_encoder[3]], axis=3)
    main_path = res_block(main_path, [256, 256], [(1, 1), (1, 1)])

    main_path = UpSampling2D(size=(2, 2))(main_path)
    main_path = concatenate([main_path, from_encoder[2]], axis=3)
    main_path = res_block(main_path, [256, 256], [(1, 1), (1, 1)])

    main_path = UpSampling2D(size=(2, 2))(main_path)
    main_path = concatenate([main_path, from_encoder[1]], axis=3)
    main_path = res_block(main_path, [128, 128], [(1, 1), (1, 1)])

    main_path = UpSampling2D(size=(2, 2))(main_path)
    main_path = concatenate([main_path, from_encoder[0]], axis=3)
    main_path = res_block(main_path, [64, 64], [(1, 1), (1, 1)])

    return main_path


def validate_input(x):
    if x.shape.as_list()[1:-1] != [512, 512]:
        pad = [(512 - int(x.shape[1])) // 2, (512 - int(x.shape[2])) // 2] 
        padding = tf.constant([[0, 0], pad, pad, [0, 0]])
        return tf.pad(x, paddings=padding, mode='REFLECT', constant_values=0)
    else:
        return x

def validate_output(x):
    if x.shape.as_list()[1:-1] != [324, 324]:
        pad = [(512 - int(x.shape[1])) // 2, (512 - int(x.shape[2])) // 2] 
        padding = tf.constant([[0, 0], pad, pad, [0, 0]])
        return tf.pad(x, paddings=padding, mode='REFLECT', constant_values=0)
    else:
        return x
    
def deep_residual_unet(input_shape=(128, 128, 3)):
    inputs = Input(shape=input_shape)
    
    to_decoder = encoder(validate_input(x=inputs))
    
    path = BatchNormalization()(to_decoder[-1])
    
    path = Activation(activation='relu')(path)
    
    path = Conv2D(filters=1024, kernel_size=(3, 3), padding='same', strides=(2, 2))(path)
    

    path = decoder(path, from_encoder=to_decoder)

    output = Conv2D(filters=3, kernel_size=(1, 1), activation='softmax')(path)

    return Model(inputs=[inputs], outputs=[output])

# %%
model = deep_residual_unet()
model.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_45 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# tf.compat.v1.pad_21 (TFOpLambda (None, 512, 512, 3)  0           input_45[0][0]
# __________________________________________________________________________________________________
# conv2d_784 (Conv2D)             (None, 512, 512, 64) 1792        tf.compat.v1.pad_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_734 (BatchN (None, 512, 512, 64) 256         conv2d_784[0][0]
# __________________________________________________________________________________________________
# conv2d_786 (Conv2D)             (None, 512, 512, 64) 256         tf.compat.v1.pad_21[0][0]
# __________________________________________________________________________________________________
# activation_488 (Activation)     (None, 512, 512, 64) 0           batch_normalization_734[0][0]
# __________________________________________________________________________________________________
# batch_normalization_735 (BatchN (None, 512, 512, 64) 256         conv2d_786[0][0]
# __________________________________________________________________________________________________
# conv2d_785 (Conv2D)             (None, 512, 512, 64) 36928       activation_488[0][0]
# __________________________________________________________________________________________________
# add_245 (Add)                   (None, 512, 512, 64) 0           batch_normalization_735[0][0]
#                                                                  conv2d_785[0][0]
# __________________________________________________________________________________________________
# batch_normalization_736 (BatchN (None, 512, 512, 64) 256         add_245[0][0]
# __________________________________________________________________________________________________
# activation_489 (Activation)     (None, 512, 512, 64) 0           batch_normalization_736[0][0]
# __________________________________________________________________________________________________
# conv2d_787 (Conv2D)             (None, 512, 512, 64) 36928       activation_489[0][0]
# __________________________________________________________________________________________________
# batch_normalization_737 (BatchN (None, 512, 512, 64) 256         conv2d_787[0][0]
# __________________________________________________________________________________________________
# conv2d_789 (Conv2D)             (None, 512, 512, 64) 4160        add_245[0][0]
# __________________________________________________________________________________________________
# activation_490 (Activation)     (None, 512, 512, 64) 0           batch_normalization_737[0][0]
# __________________________________________________________________________________________________
# batch_normalization_738 (BatchN (None, 512, 512, 64) 256         conv2d_789[0][0]
# __________________________________________________________________________________________________
# conv2d_788 (Conv2D)             (None, 512, 512, 64) 36928       activation_490[0][0]
# __________________________________________________________________________________________________
# add_246 (Add)                   (None, 512, 512, 64) 0           batch_normalization_738[0][0]
#                                                                  conv2d_788[0][0]
# __________________________________________________________________________________________________
# batch_normalization_739 (BatchN (None, 512, 512, 64) 256         add_246[0][0]
# __________________________________________________________________________________________________
# activation_491 (Activation)     (None, 512, 512, 64) 0           batch_normalization_739[0][0]
# __________________________________________________________________________________________________
# conv2d_790 (Conv2D)             (None, 512, 512, 64) 36928       activation_491[0][0]
# __________________________________________________________________________________________________
# batch_normalization_740 (BatchN (None, 512, 512, 64) 256         conv2d_790[0][0]
# __________________________________________________________________________________________________
# conv2d_792 (Conv2D)             (None, 512, 512, 64) 4160        add_246[0][0]
# __________________________________________________________________________________________________
# activation_492 (Activation)     (None, 512, 512, 64) 0           batch_normalization_740[0][0]
# __________________________________________________________________________________________________
# batch_normalization_741 (BatchN (None, 512, 512, 64) 256         conv2d_792[0][0]
# __________________________________________________________________________________________________
# conv2d_791 (Conv2D)             (None, 512, 512, 64) 36928       activation_492[0][0]
# __________________________________________________________________________________________________
# add_247 (Add)                   (None, 512, 512, 64) 0           batch_normalization_741[0][0]
#                                                                  conv2d_791[0][0]
# __________________________________________________________________________________________________
# batch_normalization_742 (BatchN (None, 512, 512, 64) 256         add_247[0][0]
# __________________________________________________________________________________________________
# activation_493 (Activation)     (None, 512, 512, 64) 0           batch_normalization_742[0][0]
# __________________________________________________________________________________________________
# conv2d_793 (Conv2D)             (None, 512, 512, 64) 36928       activation_493[0][0]
# __________________________________________________________________________________________________
# batch_normalization_743 (BatchN (None, 512, 512, 64) 256         conv2d_793[0][0]
# __________________________________________________________________________________________________
# conv2d_795 (Conv2D)             (None, 512, 512, 64) 4160        add_247[0][0]
# __________________________________________________________________________________________________
# activation_494 (Activation)     (None, 512, 512, 64) 0           batch_normalization_743[0][0]
# __________________________________________________________________________________________________
# batch_normalization_744 (BatchN (None, 512, 512, 64) 256         conv2d_795[0][0]
# __________________________________________________________________________________________________
# conv2d_794 (Conv2D)             (None, 512, 512, 64) 36928       activation_494[0][0]
# __________________________________________________________________________________________________
# add_248 (Add)                   (None, 512, 512, 64) 0           batch_normalization_744[0][0]
#                                                                  conv2d_794[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 256, 256, 64) 0           add_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_745 (BatchN (None, 256, 256, 64) 256         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_495 (Activation)     (None, 256, 256, 64) 0           batch_normalization_745[0][0]
# __________________________________________________________________________________________________
# conv2d_796 (Conv2D)             (None, 256, 256, 256 147712      activation_495[0][0]
# __________________________________________________________________________________________________
# batch_normalization_746 (BatchN (None, 256, 256, 256 1024        conv2d_796[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 256, 256, 256 16640       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_496 (Activation)     (None, 256, 256, 256 0           batch_normalization_746[0][0]
# __________________________________________________________________________________________________
# batch_normalization_747 (BatchN (None, 256, 256, 256 1024        conv2d_798[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 256, 256, 256 590080      activation_496[0][0]
# __________________________________________________________________________________________________
# add_249 (Add)                   (None, 256, 256, 256 0           batch_normalization_747[0][0]
#                                                                  conv2d_797[0][0]
# __________________________________________________________________________________________________
# batch_normalization_748 (BatchN (None, 256, 256, 256 1024        add_249[0][0]
# __________________________________________________________________________________________________
# activation_497 (Activation)     (None, 256, 256, 256 0           batch_normalization_748[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 256, 256, 256 590080      activation_497[0][0]
# __________________________________________________________________________________________________
# batch_normalization_749 (BatchN (None, 256, 256, 256 1024        conv2d_799[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 256, 256, 256 65792       add_249[0][0]
# __________________________________________________________________________________________________
# activation_498 (Activation)     (None, 256, 256, 256 0           batch_normalization_749[0][0]
# __________________________________________________________________________________________________
# batch_normalization_750 (BatchN (None, 256, 256, 256 1024        conv2d_801[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 256, 256, 256 590080      activation_498[0][0]
# __________________________________________________________________________________________________
# add_250 (Add)                   (None, 256, 256, 256 0           batch_normalization_750[0][0]
#                                                                  conv2d_800[0][0]
# __________________________________________________________________________________________________
# batch_normalization_751 (BatchN (None, 256, 256, 256 1024        add_250[0][0]
# __________________________________________________________________________________________________
# activation_499 (Activation)     (None, 256, 256, 256 0           batch_normalization_751[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 256, 256, 256 590080      activation_499[0][0]
# __________________________________________________________________________________________________
# batch_normalization_752 (BatchN (None, 256, 256, 256 1024        conv2d_802[0][0]
# __________________________________________________________________________________________________
# conv2d_804 (Conv2D)             (None, 256, 256, 256 65792       add_250[0][0]
# __________________________________________________________________________________________________
# activation_500 (Activation)     (None, 256, 256, 256 0           batch_normalization_752[0][0]
# __________________________________________________________________________________________________
# batch_normalization_753 (BatchN (None, 256, 256, 256 1024        conv2d_804[0][0]
# __________________________________________________________________________________________________
# conv2d_803 (Conv2D)             (None, 256, 256, 256 590080      activation_500[0][0]
# __________________________________________________________________________________________________
# add_251 (Add)                   (None, 256, 256, 256 0           batch_normalization_753[0][0]
#                                                                  conv2d_803[0][0]
# __________________________________________________________________________________________________
# batch_normalization_754 (BatchN (None, 256, 256, 256 1024        add_251[0][0]
# __________________________________________________________________________________________________
# activation_501 (Activation)     (None, 256, 256, 256 0           batch_normalization_754[0][0]
# __________________________________________________________________________________________________
# conv2d_805 (Conv2D)             (None, 256, 256, 256 590080      activation_501[0][0]
# __________________________________________________________________________________________________
# batch_normalization_755 (BatchN (None, 256, 256, 256 1024        conv2d_805[0][0]
# __________________________________________________________________________________________________
# conv2d_807 (Conv2D)             (None, 256, 256, 256 65792       add_251[0][0]
# __________________________________________________________________________________________________
# activation_502 (Activation)     (None, 256, 256, 256 0           batch_normalization_755[0][0]
# __________________________________________________________________________________________________
# batch_normalization_756 (BatchN (None, 256, 256, 256 1024        conv2d_807[0][0]
# __________________________________________________________________________________________________
# conv2d_806 (Conv2D)             (None, 256, 256, 256 590080      activation_502[0][0]
# __________________________________________________________________________________________________
# add_252 (Add)                   (None, 256, 256, 256 0           batch_normalization_756[0][0]
#                                                                  conv2d_806[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 128, 128, 256 0           add_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_757 (BatchN (None, 128, 128, 256 1024        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# activation_503 (Activation)     (None, 128, 128, 256 0           batch_normalization_757[0][0]
# __________________________________________________________________________________________________
# conv2d_808 (Conv2D)             (None, 128, 128, 512 1180160     activation_503[0][0]
# __________________________________________________________________________________________________
# batch_normalization_758 (BatchN (None, 128, 128, 512 2048        conv2d_808[0][0]
# __________________________________________________________________________________________________
# conv2d_810 (Conv2D)             (None, 128, 128, 512 131584      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# activation_504 (Activation)     (None, 128, 128, 512 0           batch_normalization_758[0][0]
# __________________________________________________________________________________________________
# batch_normalization_759 (BatchN (None, 128, 128, 512 2048        conv2d_810[0][0]
# __________________________________________________________________________________________________
# conv2d_809 (Conv2D)             (None, 128, 128, 512 2359808     activation_504[0][0]
# __________________________________________________________________________________________________
# add_253 (Add)                   (None, 128, 128, 512 0           batch_normalization_759[0][0]
#                                                                  conv2d_809[0][0]
# __________________________________________________________________________________________________
# batch_normalization_760 (BatchN (None, 128, 128, 512 2048        add_253[0][0]
# __________________________________________________________________________________________________
# activation_505 (Activation)     (None, 128, 128, 512 0           batch_normalization_760[0][0]
# __________________________________________________________________________________________________
# conv2d_811 (Conv2D)             (None, 128, 128, 512 2359808     activation_505[0][0]
# __________________________________________________________________________________________________
# batch_normalization_761 (BatchN (None, 128, 128, 512 2048        conv2d_811[0][0]
# __________________________________________________________________________________________________
# conv2d_813 (Conv2D)             (None, 128, 128, 512 262656      add_253[0][0]
# __________________________________________________________________________________________________
# activation_506 (Activation)     (None, 128, 128, 512 0           batch_normalization_761[0][0]
# __________________________________________________________________________________________________
# batch_normalization_762 (BatchN (None, 128, 128, 512 2048        conv2d_813[0][0]
# __________________________________________________________________________________________________
# conv2d_812 (Conv2D)             (None, 128, 128, 512 2359808     activation_506[0][0]
# __________________________________________________________________________________________________
# add_254 (Add)                   (None, 128, 128, 512 0           batch_normalization_762[0][0]
#                                                                  conv2d_812[0][0]
# __________________________________________________________________________________________________
# batch_normalization_763 (BatchN (None, 128, 128, 512 2048        add_254[0][0]
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, 128, 128, 512 0           batch_normalization_763[0][0]
# __________________________________________________________________________________________________
# conv2d_814 (Conv2D)             (None, 128, 128, 512 2359808     activation_507[0][0]
# __________________________________________________________________________________________________
# batch_normalization_764 (BatchN (None, 128, 128, 512 2048        conv2d_814[0][0]
# __________________________________________________________________________________________________
# conv2d_816 (Conv2D)             (None, 128, 128, 512 262656      add_254[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, 128, 128, 512 0           batch_normalization_764[0][0]
# __________________________________________________________________________________________________
# batch_normalization_765 (BatchN (None, 128, 128, 512 2048        conv2d_816[0][0]
# __________________________________________________________________________________________________
# conv2d_815 (Conv2D)             (None, 128, 128, 512 2359808     activation_508[0][0]
# __________________________________________________________________________________________________
# add_255 (Add)                   (None, 128, 128, 512 0           batch_normalization_765[0][0]
#                                                                  conv2d_815[0][0]
# __________________________________________________________________________________________________
# batch_normalization_766 (BatchN (None, 128, 128, 512 2048        add_255[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, 128, 128, 512 0           batch_normalization_766[0][0]
# __________________________________________________________________________________________________
# conv2d_817 (Conv2D)             (None, 128, 128, 512 2359808     activation_509[0][0]
# __________________________________________________________________________________________________
# batch_normalization_767 (BatchN (None, 128, 128, 512 2048        conv2d_817[0][0]
# __________________________________________________________________________________________________
# conv2d_819 (Conv2D)             (None, 128, 128, 512 262656      add_255[0][0]
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 128, 128, 512 0           batch_normalization_767[0][0]
# __________________________________________________________________________________________________
# batch_normalization_768 (BatchN (None, 128, 128, 512 2048        conv2d_819[0][0]
# __________________________________________________________________________________________________
# conv2d_818 (Conv2D)             (None, 128, 128, 512 2359808     activation_510[0][0]
# __________________________________________________________________________________________________
# add_256 (Add)                   (None, 128, 128, 512 0           batch_normalization_768[0][0]
#                                                                  conv2d_818[0][0]
# __________________________________________________________________________________________________
# batch_normalization_769 (BatchN (None, 128, 128, 512 2048        add_256[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 128, 128, 512 0           batch_normalization_769[0][0]
# __________________________________________________________________________________________________
# conv2d_820 (Conv2D)             (None, 128, 128, 512 2359808     activation_511[0][0]
# __________________________________________________________________________________________________
# batch_normalization_770 (BatchN (None, 128, 128, 512 2048        conv2d_820[0][0]
# __________________________________________________________________________________________________
# conv2d_822 (Conv2D)             (None, 128, 128, 512 262656      add_256[0][0]
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 128, 128, 512 0           batch_normalization_770[0][0]
# __________________________________________________________________________________________________
# batch_normalization_771 (BatchN (None, 128, 128, 512 2048        conv2d_822[0][0]
# __________________________________________________________________________________________________
# conv2d_821 (Conv2D)             (None, 128, 128, 512 2359808     activation_512[0][0]
# __________________________________________________________________________________________________
# add_257 (Add)                   (None, 128, 128, 512 0           batch_normalization_771[0][0]
#                                                                  conv2d_821[0][0]
# __________________________________________________________________________________________________
# batch_normalization_772 (BatchN (None, 128, 128, 512 2048        add_257[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 128, 128, 512 0           batch_normalization_772[0][0]
# __________________________________________________________________________________________________
# conv2d_823 (Conv2D)             (None, 128, 128, 512 2359808     activation_513[0][0]
# __________________________________________________________________________________________________
# batch_normalization_773 (BatchN (None, 128, 128, 512 2048        conv2d_823[0][0]
# __________________________________________________________________________________________________
# conv2d_825 (Conv2D)             (None, 128, 128, 512 262656      add_257[0][0]
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 128, 128, 512 0           batch_normalization_773[0][0]
# __________________________________________________________________________________________________
# batch_normalization_774 (BatchN (None, 128, 128, 512 2048        conv2d_825[0][0]
# __________________________________________________________________________________________________
# conv2d_824 (Conv2D)             (None, 128, 128, 512 2359808     activation_514[0][0]
# __________________________________________________________________________________________________
# add_258 (Add)                   (None, 128, 128, 512 0           batch_normalization_774[0][0]
#                                                                  conv2d_824[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 64, 64, 512)  0           add_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_775 (BatchN (None, 64, 64, 512)  2048        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 64, 64, 512)  0           batch_normalization_775[0][0]
# __________________________________________________________________________________________________
# conv2d_826 (Conv2D)             (None, 32, 32, 1024) 4719616     activation_515[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_99 (UpSampling2D) (None, 64, 64, 1024) 0           conv2d_826[0][0]
# __________________________________________________________________________________________________
# concatenate_99 (Concatenate)    (None, 64, 64, 1536) 0           up_sampling2d_99[0][0]
#                                                                  max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_776 (BatchN (None, 64, 64, 1536) 6144        concatenate_99[0][0]
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 64, 64, 1536) 0           batch_normalization_776[0][0]
# __________________________________________________________________________________________________
# conv2d_827 (Conv2D)             (None, 64, 64, 256)  3539200     activation_516[0][0]
# __________________________________________________________________________________________________
# batch_normalization_777 (BatchN (None, 64, 64, 256)  1024        conv2d_827[0][0]
# __________________________________________________________________________________________________
# conv2d_829 (Conv2D)             (None, 64, 64, 256)  393472      concatenate_99[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 64, 64, 256)  0           batch_normalization_777[0][0]
# __________________________________________________________________________________________________
# batch_normalization_778 (BatchN (None, 64, 64, 256)  1024        conv2d_829[0][0]
# __________________________________________________________________________________________________
# conv2d_828 (Conv2D)             (None, 64, 64, 256)  590080      activation_517[0][0]
# __________________________________________________________________________________________________
# add_259 (Add)                   (None, 64, 64, 256)  0           batch_normalization_778[0][0]
#                                                                  conv2d_828[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_100 (UpSampling2D (None, 128, 128, 256 0           add_259[0][0]
# __________________________________________________________________________________________________
# concatenate_100 (Concatenate)   (None, 128, 128, 512 0           up_sampling2d_100[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_779 (BatchN (None, 128, 128, 512 2048        concatenate_100[0][0]
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, 128, 128, 512 0           batch_normalization_779[0][0]
# __________________________________________________________________________________________________
# conv2d_830 (Conv2D)             (None, 128, 128, 256 1179904     activation_518[0][0]
# __________________________________________________________________________________________________
# batch_normalization_780 (BatchN (None, 128, 128, 256 1024        conv2d_830[0][0]
# __________________________________________________________________________________________________
# conv2d_832 (Conv2D)             (None, 128, 128, 256 131328      concatenate_100[0][0]
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, 128, 128, 256 0           batch_normalization_780[0][0]
# __________________________________________________________________________________________________
# batch_normalization_781 (BatchN (None, 128, 128, 256 1024        conv2d_832[0][0]
# __________________________________________________________________________________________________
# conv2d_831 (Conv2D)             (None, 128, 128, 256 590080      activation_519[0][0]
# __________________________________________________________________________________________________
# add_260 (Add)                   (None, 128, 128, 256 0           batch_normalization_781[0][0]
#                                                                  conv2d_831[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_101 (UpSampling2D (None, 256, 256, 256 0           add_260[0][0]
# __________________________________________________________________________________________________
# concatenate_101 (Concatenate)   (None, 256, 256, 320 0           up_sampling2d_101[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_782 (BatchN (None, 256, 256, 320 1280        concatenate_101[0][0]
# __________________________________________________________________________________________________
# activation_520 (Activation)     (None, 256, 256, 320 0           batch_normalization_782[0][0]
# __________________________________________________________________________________________________
# conv2d_833 (Conv2D)             (None, 256, 256, 128 368768      activation_520[0][0]
# __________________________________________________________________________________________________
# batch_normalization_783 (BatchN (None, 256, 256, 128 512         conv2d_833[0][0]
# __________________________________________________________________________________________________
# conv2d_835 (Conv2D)             (None, 256, 256, 128 41088       concatenate_101[0][0]
# __________________________________________________________________________________________________
# activation_521 (Activation)     (None, 256, 256, 128 0           batch_normalization_783[0][0]
# __________________________________________________________________________________________________
# batch_normalization_784 (BatchN (None, 256, 256, 128 512         conv2d_835[0][0]
# __________________________________________________________________________________________________
# conv2d_834 (Conv2D)             (None, 256, 256, 128 147584      activation_521[0][0]
# __________________________________________________________________________________________________
# add_261 (Add)                   (None, 256, 256, 128 0           batch_normalization_784[0][0]
#                                                                  conv2d_834[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_102 (UpSampling2D (None, 512, 512, 128 0           add_261[0][0]
# __________________________________________________________________________________________________
# concatenate_102 (Concatenate)   (None, 512, 512, 192 0           up_sampling2d_102[0][0]
#                                                                  add_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_785 (BatchN (None, 512, 512, 192 768         concatenate_102[0][0]
# __________________________________________________________________________________________________
# activation_522 (Activation)     (None, 512, 512, 192 0           batch_normalization_785[0][0]
# __________________________________________________________________________________________________
# conv2d_836 (Conv2D)             (None, 512, 512, 64) 110656      activation_522[0][0]
# __________________________________________________________________________________________________
# batch_normalization_786 (BatchN (None, 512, 512, 64) 256         conv2d_836[0][0]
# __________________________________________________________________________________________________
# conv2d_838 (Conv2D)             (None, 512, 512, 64) 12352       concatenate_102[0][0]
# __________________________________________________________________________________________________
# activation_523 (Activation)     (None, 512, 512, 64) 0           batch_normalization_786[0][0]
# __________________________________________________________________________________________________
# batch_normalization_787 (BatchN (None, 512, 512, 64) 256         conv2d_838[0][0]
# __________________________________________________________________________________________________
# conv2d_837 (Conv2D)             (None, 512, 512, 64) 36928       activation_523[0][0]
# __________________________________________________________________________________________________
# add_262 (Add)                   (None, 512, 512, 64) 0           batch_normalization_787[0][0]
#                                                                  conv2d_837[0][0]
# __________________________________________________________________________________________________
# conv2d_839 (Conv2D)             (None, 512, 512, 3)  195         add_262[0][0]
# ==================================================================================================
# Total params: 45,277,571
# Trainable params: 45,243,523
# Non-trainable params: 34,048
# __________________________________________________________________________________________________
